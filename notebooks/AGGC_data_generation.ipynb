# %%
import csv
import argparse
import zipfile
import pandas as pd
from pathlib import Path
import numpy as np, scipy.sparse as sp
import sys
from shapely.geometry import box, shape, Polygon,mapping

import os, json, h5py
from collections import Counter
import matplotlib.pyplot as plt
import geopandas as gpd
import pyvips
from pathlib import Path

os.chdir('/scratch/users/ntu/lizh0106/nscc_work')
print(os.getcwd())
# Out:
# /scratch/users/ntu/lizh0106/nscc_work

# %%
df = pd.read_csv("WsiBERT/AGGC_metadata.csv")
#df.head(2)

# %%
feature_folder = "AGGC_Features/Train_all_features"
mask_folder = "AGGC_Annotation/Annotation_all_file"

tile_size = 512

def read_h5(h5_path):  ##features
  with h5py.File(h5_path, "r") as f:
      coords = f["coords"][:]
      features = f["features"][:]
  return coords, features

def load_mask_vips(path: Path):
    img = pyvips.Image.new_from_file(str(path), access="sequential")
    arr = np.frombuffer(img.write_to_memory(), dtype=np.uint8)
    arr = arr.reshape(img.height, img.width, img.bands)
    arr = (arr > 0).astype(np.uint8)
    if arr.ndim == 3 and arr.shape[2] == 1:
        arr = arr[..., 0]
    return arr

# %%
targets_list = []
masks_list   = []
names_list   = []

for i, row in df.iterrows():
    wsi_id = row["WSI File Names"]      # for example "Subset1_Train_1"
    print(f"opening {wsi_id}")
    h5_path = os.path.join(feature_folder, wsi_id + ".h5")
    anno_dir = os.path.join(mask_folder, wsi_id)

    coords, features = read_h5(h5_path)

    has_G3 = not pd.isna(row["G3_Mask"])
    has_G4 = not pd.isna(row["G4_Mask"])
    has_G5 = not pd.isna(row["G5_Mask"])

    g3 = g4 = g5 = None

    H = W = None

    if has_G3:
        g3 = load_mask_vips(Path(anno_dir) / "G3_Mask.tif")
        H, W = g3.shape
    if has_G4:
        g4 = load_mask_vips(Path(anno_dir) / "G4_Mask.tif")
        H, W = g4.shape if H is None else (H, W)
    if has_G5:
        g5 = load_mask_vips(Path(anno_dir) / "G5_Mask.tif")
        H, W = g5.shape if H is None else (H, W)

    if H is None:
        print("H = None, NO G3/G4/G5 Annotation")
        continue

    if g3 is None: g3 = np.zeros((H, W), np.uint8)
    if g4 is None: g4 = np.zeros((H, W), np.uint8)
    if g5 is None: g5 = np.zeros((H, W), np.uint8)

    tumor_union = (g3 | g4 | g5).astype(np.uint8)
    other = (1 - tumor_union).astype(np.uint8)

    out_of_bound = 0

    for (x, y) in coords:  
        x = int(x); y = int(y)
        if x + tile_size > W or y + tile_size > H:
            # out of bound = other class
            t = [0., 0., 0., 1.]
            m = [0, 0, 0, 1]
            out_of_bound += 1
        else:
            patch_g3 = g3[y:y+tile_size, x:x+tile_size]
            patch_g4 = g4[y:y+tile_size, x:x+tile_size]
            patch_g5 = g5[y:y+tile_size, x:x+tile_size]
            patch_ot = other[y:y+tile_size, x:x+tile_size]

            area = tile_size * tile_size

            r3 = float(patch_g3.sum()) / area
            r4 = float(patch_g4.sum()) / area
            r5 = float(patch_g5.sum()) / area
            ro = float(patch_ot.sum()) / area

            t = [r3, r4, r5, ro]

            m = [int(has_G3),int(has_G4), int(has_G5),1]

        targets_list.append(t)
        masks_list.append(m)
        names_list.append(wsi_id)

    print(f"{wsi_id}: {out_of_bound} tiles out of mask range and was assigned to the other class")

targets = np.array(targets_list, dtype=np.float32) 
masks   = np.array(masks_list,   dtype=np.float32)
names   = np.array(names_list,   dtype="U32")

np.savez_compressed(
    "WsiBERT/AGGC_tile_targets_masks_names.npz",
    targets=targets,
    masks=masks,
    names=names,)
# Out:
# opening Subset1_Train_1
# Subset1_Train_1: 100 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_10
# Subset1_Train_10: 28 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_100
# Subset1_Train_100: 0 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_101
# Subset1_Train_101: 0 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_102
# Subset1_Train_102: 12 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_103
# Subset1_Train_103: 51 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_104
# Subset1_Train_104: 62 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_105
# Subset1_Train_105: 0 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_11
# Subset1_Train_11: 49 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_12
# Subset1_Train_12: 0 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_13
# Subset1_Train_13: 65 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_14
# Subset1_Train_14: 31 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_15
# Subset1_Train_15: 15 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_16
# Subset1_Train_16: 0 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_17
# Subset1_Train_17: 121 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_18
# Subset1_Train_18: 0 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_19
# Subset1_Train_19: 0 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_2
# Subset1_Train_2: 18 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_20
# Subset1_Train_20: 14 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_21
# Subset1_Train_21: 0 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_22
# Subset1_Train_22: 59 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_23
# Subset1_Train_23: 0 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_24
# Subset1_Train_24: 10 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_25
# Subset1_Train_25: 0 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_26
# Subset1_Train_26: 5 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_27
# Subset1_Train_27: 0 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_28
# Subset1_Train_28: 0 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_29
# Subset1_Train_29: 3 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_3
# Subset1_Train_3: 29 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_30
# Subset1_Train_30: 0 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_31
# Subset1_Train_31: 0 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_32
# Subset1_Train_32: 128 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_33
# Subset1_Train_33: 24 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_34
# Subset1_Train_34: 74 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_35
# Subset1_Train_35: 0 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_36
# Subset1_Train_36: 0 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_37
# Subset1_Train_37: 0 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_38
# Subset1_Train_38: 22 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_39
# Subset1_Train_39: 2 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_4
# Subset1_Train_4: 65 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_40
# Subset1_Train_40: 0 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_41
# Subset1_Train_41: 61 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_42
# Subset1_Train_42: 29 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_43
# Subset1_Train_43: 9 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_44
# Subset1_Train_44: 4 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_45
# Subset1_Train_45: 17 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_46
# Subset1_Train_46: 9 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_47
# Subset1_Train_47: 49 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_48
# Subset1_Train_48: 0 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_49
# Subset1_Train_49: 0 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_5
# Subset1_Train_5: 0 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_50
# Subset1_Train_50: 0 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_51
# Subset1_Train_51: 191 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_52
# Subset1_Train_52: 0 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_53
# Subset1_Train_53: 0 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_54
# Subset1_Train_54: 24 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_55
# Subset1_Train_55: 0 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_56
# Subset1_Train_56: 0 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_57
# Subset1_Train_57: 28 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_58
# Subset1_Train_58: 81 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_59
# Subset1_Train_59: 0 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_6
# Subset1_Train_6: 0 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_60
# Subset1_Train_60: 105 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_61
# Subset1_Train_61: 49 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_62
# Subset1_Train_62: 0 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_63
# Subset1_Train_63: 2 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_64
# Subset1_Train_64: 98 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_65
# Subset1_Train_65: 0 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_66
# Subset1_Train_66: 76 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_67
# Subset1_Train_67: 0 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_68
# Subset1_Train_68: 50 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_69
# Subset1_Train_69: 0 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_7
# Subset1_Train_7: 3 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_70
# Subset1_Train_70: 0 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_71
# Subset1_Train_71: 0 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_72
# Subset1_Train_72: 185 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_73
# Subset1_Train_73: 0 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_74
# Subset1_Train_74: 9 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_75
# Subset1_Train_75: 0 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_76
# Subset1_Train_76: 0 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_77
# Subset1_Train_77: 55 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_78
# Subset1_Train_78: 41 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_79
# Subset1_Train_79: 127 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_8
# Subset1_Train_8: 10 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_80
# Subset1_Train_80: 0 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_81
# Subset1_Train_81: 15 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_82
# Subset1_Train_82: 55 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_83
# Subset1_Train_83: 57 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_84
# Subset1_Train_84: 0 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_85
# Subset1_Train_85: 0 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_86
# Subset1_Train_86: 58 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_87
# Subset1_Train_87: 0 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_88
# Subset1_Train_88: 0 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_89
# Subset1_Train_89: 0 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_9
# Subset1_Train_9: 50 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_90
# Subset1_Train_90: 28 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_91
# Subset1_Train_91: 0 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_92
# Subset1_Train_92: 13 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_93
# Subset1_Train_93: 1 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_94
# Subset1_Train_94: 0 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_95
# Subset1_Train_95: 0 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_97
# Subset1_Train_97: 12 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_98
# Subset1_Train_98: 0 tiles out of mask range and was assigned to the other class
# opening Subset1_Train_99
# Subset1_Train_99: 68 tiles out of mask range and was assigned to the other class
# opening Subset1_Test_1
# Subset1_Test_1: 0 tiles out of mask range and was assigned to the other class
# opening Subset1_Test_10
# Subset1_Test_10: 0 tiles out of mask range and was assigned to the other class
# opening Subset1_Test_11
# Subset1_Test_11: 0 tiles out of mask range and was assigned to the other class
# opening Subset1_Test_12
# Subset1_Test_12: 33 tiles out of mask range and was assigned to the other class
# opening Subset1_Test_13
# Subset1_Test_13: 0 tiles out of mask range and was assigned to the other class
# opening Subset1_Test_14
# Subset1_Test_14: 0 tiles out of mask range and was assigned to the other class
# opening Subset1_Test_15
# Subset1_Test_15: 0 tiles out of mask range and was assigned to the other class
# opening Subset1_Test_16
# Subset1_Test_16: 0 tiles out of mask range and was assigned to the other class
# opening Subset1_Test_17
# Subset1_Test_17: 184 tiles out of mask range and was assigned to the other class
# opening Subset1_Test_18
# Subset1_Test_18: 0 tiles out of mask range and was assigned to the other class
# opening Subset1_Test_19
# Subset1_Test_19: 5 tiles out of mask range and was assigned to the other class
# opening Subset1_Test_2
# Subset1_Test_2: 93 tiles out of mask range and was assigned to the other class
# opening Subset1_Test_20
# Subset1_Test_20: 37 tiles out of mask range and was assigned to the other class
# opening Subset1_Test_21
# Subset1_Test_21: 14 tiles out of mask range and was assigned to the other class
# opening Subset1_Test_22
# Subset1_Test_22: 31 tiles out of mask range and was assigned to the other class
# opening Subset1_Test_23
# Subset1_Test_23: 2 tiles out of mask range and was assigned to the other class
# opening Subset1_Test_24
# Subset1_Test_24: 19 tiles out of mask range and was assigned to the other class
# opening Subset1_Test_25
# Subset1_Test_25: 46 tiles out of mask range and was assigned to the other class
# opening Subset1_Test_26
# Subset1_Test_26: 94 tiles out of mask range and was assigned to the other class
# opening Subset1_Test_27
# Subset1_Test_27: 0 tiles out of mask range and was assigned to the other class
# opening Subset1_Test_28
# Subset1_Test_28: 48 tiles out of mask range and was assigned to the other class
# opening Subset1_Test_29
# Subset1_Test_29: 0 tiles out of mask range and was assigned to the other class
# opening Subset1_Test_3
# Subset1_Test_3: 1 tiles out of mask range and was assigned to the other class
# opening Subset1_Test_30
# Subset1_Test_30: 6 tiles out of mask range and was assigned to the other class
# opening Subset1_Test_31
# Subset1_Test_31: 0 tiles out of mask range and was assigned to the other class
# opening Subset1_Test_32
# Subset1_Test_32: 90 tiles out of mask range and was assigned to the other class
# opening Subset1_Test_33
# Subset1_Test_33: 6 tiles out of mask range and was assigned to the other class
# opening Subset1_Test_34
# Subset1_Test_34: 0 tiles out of mask range and was assigned to the other class
# opening Subset1_Test_35
# Subset1_Test_35: 0 tiles out of mask range and was assigned to the other class
# opening Subset1_Test_36
# Subset1_Test_36: 4 tiles out of mask range and was assigned to the other class
# opening Subset1_Test_37
# Subset1_Test_37: 0 tiles out of mask range and was assigned to the other class
# opening Subset1_Test_38
# Subset1_Test_38: 37 tiles out of mask range and was assigned to the other class
# opening Subset1_Test_39
# Subset1_Test_39: 46 tiles out of mask range and was assigned to the other class
# opening Subset1_Test_4
# Subset1_Test_4: 5 tiles out of mask range and was assigned to the other class
# opening Subset1_Test_40
# Subset1_Test_40: 9 tiles out of mask range and was assigned to the other class
# opening Subset1_Test_41
# Subset1_Test_41: 18 tiles out of mask range and was assigned to the other class
# opening Subset1_Test_42
# Subset1_Test_42: 3 tiles out of mask range and was assigned to the other class
# opening Subset1_Test_43
# Subset1_Test_43: 0 tiles out of mask range and was assigned to the other class
# opening Subset1_Test_44
# Subset1_Test_44: 0 tiles out of mask range and was assigned to the other class
# opening Subset1_Test_45
# Subset1_Test_45: 0 tiles out of mask range and was assigned to the other class
# opening Subset1_Test_5
# Subset1_Test_5: 0 tiles out of mask range and was assigned to the other class
# opening Subset1_Test_6
# Subset1_Test_6: 0 tiles out of mask range and was assigned to the other class
# opening Subset1_Test_7
# Subset1_Test_7: 0 tiles out of mask range and was assigned to the other class
# opening Subset1_Test_8
# Subset1_Test_8: 49 tiles out of mask range and was assigned to the other class
# opening Subset1_Test_9
# Subset1_Test_9: 27 tiles out of mask range and was assigned to the other class
# opening Subset3_Train_10_Akoya
# Subset3_Train_10_Akoya: 0 tiles out of mask range and was assigned to the other class
# opening Subset3_Train_11_Akoya
# Subset3_Train_11_Akoya: 0 tiles out of mask range and was assigned to the other class
# opening Subset3_Train_12_Akoya
# Subset3_Train_12_Akoya: 75 tiles out of mask range and was assigned to the other class
# opening Subset3_Train_13_Akoya
# Subset3_Train_13_Akoya: 0 tiles out of mask range and was assigned to the other class
# opening Subset3_Train_14_Akoya
# Subset3_Train_14_Akoya: 0 tiles out of mask range and was assigned to the other class
# opening Subset3_Train_15_Akoya
# Subset3_Train_15_Akoya: 0 tiles out of mask range and was assigned to the other class
# opening Subset3_Train_16_Akoya
# Subset3_Train_16_Akoya: 0 tiles out of mask range and was assigned to the other class
# opening Subset3_Train_17_Akoya
# Subset3_Train_17_Akoya: 0 tiles out of mask range and was assigned to the other class
# opening Subset3_Train_18_Akoya
# Subset3_Train_18_Akoya: 43 tiles out of mask range and was assigned to the other class
# opening Subset3_Train_19_Akoya
# Subset3_Train_19_Akoya: 0 tiles out of mask range and was assigned to the other class
# opening Subset3_Train_1_Akoya
# Subset3_Train_1_Akoya: 74 tiles out of mask range and was assigned to the other class
# opening Subset3_Train_20_Akoya
# Subset3_Train_20_Akoya: 0 tiles out of mask range and was assigned to the other class
# opening Subset3_Train_21_Akoya
# Subset3_Train_21_Akoya: 44 tiles out of mask range and was assigned to the other class
# opening Subset3_Train_22_Akoya
# Subset3_Train_22_Akoya: 40 tiles out of mask range and was assigned to the other class
# opening Subset3_Train_23_Akoya
# Subset3_Train_23_Akoya: 66 tiles out of mask range and was assigned to the other class
# opening Subset3_Train_24_Akoya
# Subset3_Train_24_Akoya: 24 tiles out of mask range and was assigned to the other class
# opening Subset3_Train_25_Akoya
# Subset3_Train_25_Akoya: 105 tiles out of mask range and was assigned to the other class
# opening Subset3_Train_26_Akoya
# Subset3_Train_26_Akoya: 68 tiles out of mask range and was assigned to the other class
# opening Subset3_Train_2_Akoya
# Subset3_Train_2_Akoya: 36 tiles out of mask range and was assigned to the other class
# opening Subset3_Train_3_Akoya
# Subset3_Train_3_Akoya: 50 tiles out of mask range and was assigned to the other class
# opening Subset3_Train_4_Akoya
# Subset3_Train_4_Akoya: 152 tiles out of mask range and was assigned to the other class
# opening Subset3_Train_5_Akoya
# Subset3_Train_5_Akoya: 0 tiles out of mask range and was assigned to the other class
# opening Subset3_Train_6_Akoya
# Subset3_Train_6_Akoya: 0 tiles out of mask range and was assigned to the other class
# opening Subset3_Train_7_Akoya
# Subset3_Train_7_Akoya: 24 tiles out of mask range and was assigned to the other class
# opening Subset3_Train_8_Akoya
# Subset3_Train_8_Akoya: 0 tiles out of mask range and was assigned to the other class
# opening Subset3_Train_9_Akoya
# Subset3_Train_9_Akoya: 5 tiles out of mask range and was assigned to the other class
# opening Subset3_Test_10_Akoya
# Subset3_Test_10_Akoya: 0 tiles out of mask range and was assigned to the other class
# opening Subset3_Test_11_Akoya
# Subset3_Test_11_Akoya: 33 tiles out of mask range and was assigned to the other class
# opening Subset3_Test_12_Akoya
# Subset3_Test_12_Akoya: 0 tiles out of mask range and was assigned to the other class
# opening Subset3_Test_1_Akoya
# Subset3_Test_1_Akoya: 151 tiles out of mask range and was assigned to the other class
# opening Subset3_Test_2_Akoya
# Subset3_Test_2_Akoya: 45 tiles out of mask range and was assigned to the other class
# opening Subset3_Test_3_Akoya
# Subset3_Test_3_Akoya: 49 tiles out of mask range and was assigned to the other class
# opening Subset3_Test_4_Akoya
# Subset3_Test_4_Akoya: 77 tiles out of mask range and was assigned to the other class
# opening Subset3_Test_5_Akoya
# Subset3_Test_5_Akoya: 0 tiles out of mask range and was assigned to the other class
# opening Subset3_Test_6_Akoya
# Subset3_Test_6_Akoya: 81 tiles out of mask range and was assigned to the other class
# opening Subset3_Test_7_Akoya
# Subset3_Test_7_Akoya: 57 tiles out of mask range and was assigned to the other class
# opening Subset3_Test_8_Akoya
# Subset3_Test_8_Akoya: 4 tiles out of mask range and was assigned to the other class
# opening Subset3_Test_9_Akoya
# Subset3_Test_9_Akoya: 210 tiles out of mask range and was assigned to the other class

# %%
tmp = np.load("WsiBERT/AGGC_tile_targets_masks_names.npz")
tmp["targets"].shape
